# %%
import pandas as pd

data_root = "./"
av_df = pd.read_csv(data_root + "av_data.csv")

# %%
av_df
# Out:
#         participant_id     media_id media_modality   arousal   valence  \
# 0                    4  1cQh1ccqu8M    muted_video  0.000000  0.000000
# 1                    4  1cQh1ccqu8M    muted_video  0.000000  0.000000
# 2                    4  1cQh1ccqu8M    muted_video  0.000000  0.000000
# 3                    4  1cQh1ccqu8M    muted_video  0.000000  0.000000
# 4                    4  1cQh1ccqu8M    muted_video  0.000000  0.000000
# ...                ...          ...            ...       ...       ...
# 179322              11  cSnkWzZ7ZAA    muted_video  0.686957  0.269565
# 179323              11  cSnkWzZ7ZAA    muted_video  0.686957  0.269565
# 179324              11  cSnkWzZ7ZAA    muted_video  0.686957  0.269565
# 179325              11  cSnkWzZ7ZAA    muted_video  0.686957  0.269565
# 179326              11  cSnkWzZ7ZAA    muted_video  0.678261  0.269565
#
#         timestamp overlay_type  seq
# 0             0.5        false    0
# 1             1.0        false    1
# ...

# %%
av_df = av_df[av_df['media_modality'] == 'music']
av_df
# Out:
#         participant_id     media_id media_modality   arousal   valence  \
# 2621                13  OMOGaugKpzs          music  0.000000  0.000000
# 2622                13  OMOGaugKpzs          music  0.026087  0.000000
# 2623                13  OMOGaugKpzs          music  0.026087  0.000000
# 2624                13  OMOGaugKpzs          music  0.026087  0.000000
# 2625                13  OMOGaugKpzs          music  0.026087  0.000000
# ...                ...          ...            ...       ...       ...
# 178962              11  tg00YEETFzg          music  0.513043 -0.078261
# 178963              11  tg00YEETFzg          music  0.547826 -0.008696
# 178964              11  tg00YEETFzg          music  0.556522 -0.008696
# 178965              11  tg00YEETFzg          music  0.573913 -0.008696
# 178966              11  tg00YEETFzg          music  0.591304 -0.017391
#
#         timestamp overlay_type  seq
# 2621          0.0   irrelevant    0
# 2622          0.7   irrelevant    1
# ...

# %%
uniq = av_df['media_id'].unique()
len(uniq)
uniq
# Out:
# array(['OMOGaugKpzs', '9bZkp7q19f0', 'yyDUC1LUXSU', 'cSnkWzZ7ZAA',
#        'ebXbLfLACGM', '4JipHEz53sU', 'J9NQFACZYEU', 'KlyXNRrsk4A', 'Dsp',
#        'J3UjJ4wKLkg', 'nCkpzqqog4k', 'S9bCLPwzSC0', 'Ahha3Cqe',
#        'CevxZvSJLk8', 'bjgFH01k0gU', 'kffacxfA7G4', 'btPJPFnesV4',
#        '8xg3vE8Ie', 'dvgZkm1xWPE', 'n4RjJKxsamQ', 'vNoKguSdy4Y',
#        'VPRjCeoBqrI', 'E8gmARGvPlI', 'o3mP3mJDL2k', '8SbUC-UaAxE', 'hT',
#        'ASO', 'tg00YEETFzg', 'RB-RcX5DS5A', 'Zi', 'EkHTsc9PU2A',
#        'IcrbM1l', 'LjhCEhWiKXk', 'j5-yKhDd64s', 'kTHNpusq654',
#        'QGJuMBdaqIw', 'U0CGsw6h60k', 'LrUvu1mlWco', 'OZLUa8JUR18',
#        'AtKZKl7Bgu0', 'QJO3ROT-A4E', 'k0BWlvnBmIE', 'e-fA-gBCkj0',
#        '7RMQksXpQSk', 'weRHyjj34ZE', 'My2FRPA3Gf8', 'iS1g8G',
#        'lDK9QqIzhwk', 'wyx6JDQCslE', '47dtFZ8CFo8', 'KRaWnd3LJfs',
#        'rtOvBOTyX00', '1cQh1ccqu8M', 'W-TE', '8WYHDfJDPDc', 'yd8jh9QYfEs',
#        'fV4DiAyExN0', '3YxaaGgTQYM', 'kXYiU', 'JRfuAukYTKg',
# ...

# %%
urls = pd.read_csv(data_root + "video_urls.csv")

# %%
urls
# Out:
#        video_id
# 0   lDK9QqIzhwk
# 1   4JipHEz53sU
# 2   j5-yKhDd64s
# 3   J9NQFACZYEU
# 4   t5Sd5c4o9UM
# ..          ...
# 76  8SbUC-UaAxE
# 77  WA4iX5D9Z64
# 78  bjgFH01k0gU
# 79  3O1_3zBUKM8
# 80  8WYHDfJDPDc
#
# [81 rows x 1 columns]

# %%
import numpy as np
np.array(av_df['timestamp'])
# Out:
# array([ 0. ,  0.7,  1. , ..., 58.9, 59.4, 59.9])
